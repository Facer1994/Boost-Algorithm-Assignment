# %%
import pandas as pd

# %%
dataset=pd.read_csv('insurance_pre.csv')

# %%
dataset.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges'], dtype='object')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400           1         0          0
# 1      18  33.770         1   1725.55230           0         1          1
# 2      28  33.000         3   4449.46200           0         1          1
# 3      33  22.705         0  21984.47061           0         1          1
# 4      32  28.880         0   3866.85520           0         1          1
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830           0         1          1
# 1334   18  31.920         0   2205.98080           1         0          1
# 1335   18  36.850         0   1629.83350           1         0          1
# 1336   21  25.800         0   2007.94500           1         0          1
# 1337   61  29.070         0  29141.36030           1         0          0
#
#       smoker_yes
# 0              1
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 1333           0
# 1334           0
# 1335           0
# 1336           0
# 1337           1
#
# [1338 rows x 8 columns]

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_female', 'sex_male','smoker_no', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_female  sex_male  smoker_no  smoker_yes
# 0      19  27.900         0           1         0          0           1
# 1      18  33.770         1           0         1          1           0
# 2      28  33.000         3           0         1          1           0
# 3      33  22.705         0           0         1          1           0
# 4      32  28.880         0           0         1          1           0
# ...   ...     ...       ...         ...       ...        ...         ...
# 1333   50  30.970         3           0         1          1           0
# 1334   18  31.920         0           1         0          1           0
# 1335   18  36.850         0           1         0          1           0
# 1336   21  25.800         0           1         0          1           0
# 1337   61  29.070         0           1         0          0           1
#
# [1338 rows x 7 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test=train_test_split(independent, dependent,test_size=0.30,random_state=0)

# %%
! pip install lightgbm
import lightgbm as ltb
# Out:
# Requirement already satisfied: lightgbm in c:\users\jayarajan\anaconda3\lib\site-packages (4.0.0)
# Requirement already satisfied: numpy in c:\users\jayarajan\anaconda3\lib\site-packages (from lightgbm) (1.23.4)
# Requirement already satisfied: scipy in c:\users\jayarajan\anaconda3\lib\site-packages (from lightgbm) (1.9.3)

# %%
regressor=ltb.LGBMRegressor(boosting_type='rf')
regressor.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# LightGBMError                             Traceback (most recent call last)
# Cell In [180], line 2
#       1 regressor=ltb.LGBMRegressor(boosting_type='rf')
# ----> 2 regressor.fit(x_train,y_train)
#
# File ~\anaconda3\lib\site-packages\lightgbm\sklearn.py:1049, in LGBMRegressor.fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1032 def fit(  # type: ignore[override]
#    1033     self,
#    1034     X: _LGBM_ScikitMatrixLike,
#    (...)
#    1046     init_model: Optional[Union[str, Path, Booster, LGBMModel]] = None
#    1047 ) -> "LGBMRegressor":
#    1048     """Docstring is inherited from the LGBMModel."""
# -> 1049     super().fit(
#    1050         X,
#    1051         y,
#    1052         sample_weight=sample_weight,
#    1053         init_score=init_score,
#    1054         eval_set=eval_set,
#    1055         eval_names=eval_names,
#    1056         eval_sample_weight=eval_sample_weight,
#    1057         eval_init_score=eval_init_score,
#    1058         eval_metric=eval_metric,
#    1059         feature_name=feature_name,
#    1060         categorical_feature=categorical_feature,
#    1061         callbacks=callbacks,
#    1062         init_model=init_model
#    1063     )
#    1064     return self
#
# File ~\anaconda3\lib\site-packages\lightgbm\sklearn.py:842, in LGBMModel.fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#     839 evals_result: _EvalResultDict = {}
#     840 callbacks.append(record_evaluation(evals_result))
# --> 842 self._Booster = train(
#     843     params=params,
#     844     train_set=train_set,
#     845     num_boost_round=self.n_estimators,
#     846     valid_sets=valid_sets,
#     847     valid_names=eval_names,
#     848     feval=eval_metrics_callable,  # type: ignore[arg-type]
#     849     init_model=init_model,
#     850     feature_name=feature_name,
#     851     callbacks=callbacks
#     852 )
#     854 self._evals_result = evals_result
#     855 self._best_iteration = self._Booster.best_iteration
#
# File ~\anaconda3\lib\site-packages\lightgbm\engine.py:245, in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, feature_name, categorical_feature, keep_training_booster, callbacks)
#     243 # construct booster
#     244 try:
# --> 245     booster = Booster(params=params, train_set=train_set)
#     246     if is_valid_contain_train:
#     247         booster.set_train_data_name(train_data_name)
#
# File ~\anaconda3\lib\site-packages\lightgbm\basic.py:3101, in Booster.__init__(self, params, train_set, model_file, model_str)
#    3099 params_str = _param_dict_to_str(params)
#    3100 self._handle = ctypes.c_void_p()
# -> 3101 _safe_call(_LIB.LGBM_BoosterCreate(
#    3102     train_set._handle,
#    3103     _c_str(params_str),
#    3104     ctypes.byref(self._handle)))
#    3105 # save reference to data
#    3106 self.train_set = train_set
#
# File ~\anaconda3\lib\site-packages\lightgbm\basic.py:237, in _safe_call(ret)
#     229 """Check the return value from C API call.
#     230
#     231 Parameters
#    (...)
#     234     The return value from C API calls.
#     235 """
#     236 if ret != 0:
# --> 237     raise LightGBMError(_LIB.LGBM_GetLastError().decode('utf-8'))
#
# LightGBMError: Check failed: (config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f) || (config->feature_fraction < 1.0f && config->feature_fraction > 0.0f) at D:\a\1\s\lightgbm-python\src\boosting\rf.hpp, line 37 .

# %%
y_predict=regressor.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score=r2_score(y_test,y_predict)
r2_score
# Out:
# 0.8685289370060291
